# %% [markdown]
# <a href="https://colab.research.google.com/github/Lalo287/Simulacion_II-Ejercios/blob/main/Ejercicio_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo de integrales por el método de Monte Carlo

# %% [markdown]
# ##Ejercicio 7:

# %% [markdown]
# **1.-  Mostrar que $\theta_1 $ es un estimador insesgado, es decir, que $E(\theta_1 ) = pc(b-a) = I$**

# %% [markdown]
# Para demostrar este ejercicio vamos utilizar esta ecuación: $ y = \sqrt((1-x^2))^3 $
#
# Consiedramos aquí la estimación de integrales unidimensionales
#
# >    $I = \int_a^b g(x)dx,$
#
# Entonces:
#
# > $I = \int_0^1 \sqrt((1-x^2))$
#
# > $I = 3\pi/16$
#
# > $I = 0.589045 = E(\theta_1 )$

# %% [markdown]
# Entoces $pc(b-a) = E(\theta_1 )$

# %%
from itertools import tee
import random
import numpy as np
import matplotlib.pyplot as plt

n = int(input("Numero de puntos que desea "))
x = np.linspace(0, 2, 1000)
y = (1-x*x)**(3/2)
dentro = 0

print ()
fig = plt.figure(1, figsize=(6, 6))
for i in range(n):
    x_1 = random.uniform(0, 1)
    y_1 = random.uniform(0, 1)
    plt.scatter(x_1, y_1, s=20, c="red")
    if (1-x_1**2)**(3/2) >= y_1 :
      dentro += 1

plt.plot(x, y, color="blue", markersize=1)

plt.title("Grafica")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid()
plt.show()

print ()
print("El valor de pc(b-a) =" , (dentro/n))
# Out:
# Numero de puntos que desea 1000
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in power
# El valor de pc(b-a) = 0.583

# %% [markdown]
# Por lo tanto $E(\theta_1 ) = pc(b-a) = I$

# %% [markdown]
# **2.- Obtener $V(\theta_1 )=\frac{I}{N}[c(b-a)-I]$**

# %%
V = (0.589045/n)*(1 - .589045)
print("El valor de V(0_1) =", V)
# Out:
# El valor de V(0_1) = 0.000242070987975
